# %%
import pandas as pd
import numpy as np
from googlesearch import search
from googleapiclient.discovery import build
import json
import pprint

# %%
## Beautiful Soup Library Way

# %%
query = "\"aww poor Tom and Harry hopefully they get back together. Harry deserves everything he is getting from Tom. please update.\""
  
for j in search(query, tld="co.in", num=20, stop = 20, pause=2): 
    print(j)
# Out:
# https://www.fanfiction.net/r/7032591/

# %%
## GOOGLE METHOD

# %%
key = 'AIzaSyClXQwJXEhv6rH3TuVRvCnnhCXipYZCSNs'
search_id = '001012738810360057588:gqoifbpjzug'

# %%
def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res

# %%
result = google_search("\"aww poor Tom and Harry hopefully they get back together. Harry deserves everything he is getting from Tom. please update.\"", key, search_id)

# %%
pp = pprint.PrettyPrinter(depth=6)
pp.pprint(result)
# Out:
# {'kind': 'customsearch#search',
#  'queries': {'request': [{'count': 10,
#                           'cx': '001012738810360057588:gqoifbpjzug',
#                           'inputEncoding': 'utf8',
#                           'outputEncoding': 'utf8',
#                           'safe': 'off',
#                           'searchTerms': '"aww poor Tom and Harry hopefully '
#                                          'they get back together. Harry '
#                                          'deserves everything he is getting '
#                                          'from Tom. please update."',
#                           'startIndex': 1,
#                           'title': 'Google Custom Search - "aww poor Tom and '
#                                    'Harry hopefully they get back together. '
#                                    'Harry deserves everything he is getting '
#                                    'from Tom. please update."'}]},
# ...

# %%
result = google_search("coffee", key, search_id)

# %%
pp = pprint.PrettyPrinter(depth=6)
pp.pprint(result)
# Out:
# {'context': {'title': 'Fanfiction.net'},
#  'items': [{'cacheId': 'U6oJMnF-eeUJ',
#             'displayLink': 'en.wikipedia.org',
#             'formattedUrl': 'https://en.wikipedia.org/wiki/Coffee',
#             'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/<b>Coffee</b>',
#             'htmlSnippet': '<b>Coffee</b> is a brewed drink prepared from '
#                            'roasted <b>coffee</b> beans, the seeds of <br>\n'
#                            'berries from certain Coffea species. The genus '
#                            'Coffea is native to tropical Africa <br>\n'
#                            'and&nbsp;...',
#             'htmlTitle': '<b>Coffee</b> - Wikipedia',
#             'kind': 'customsearch#result',
#             'link': 'https://en.wikipedia.org/wiki/Coffee',
#             'pagemap': {'cse_image': [{'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/A_small_cup_of_coffee.JPG/1200px-A_small_cup_of_coffee.JPG'}],
# ...

# %%
## From Scratch with Beautiful Soup

# %%
import urllib
from bs4 import BeautifulSoup
import requests
import webbrowser

original = "aww poor Tom and Harry, hopefully they get back together. Harry deserves everything he is getting from Tom. please update."
#text = '\"aww poor Tom and Harry, hopefully they get back together. Harry deserves everything he is getting from Tom. please update.\"'
text = '\"aww poor Jackson and Janice, hopefully they get back together. Jackson deserves everything he is getting from Janice. please update.\"'
text = urllib.parse.quote_plus(text)

url = 'https://google.com/search?q=' + text

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

for g in soup.find_all(class_='ZINbbc xpd O9g5cc uUPGi'):
    print(g.text)
    print('-----')
    print(original in g.text)
    print('-----')
# Out:
# A Place for Michael Jackson Fan Fiction! - MJ Fictionmjfiction.com › reviewsDerek what can I say about Derek, he's a reminder of who Janice was before she ... never Fathom or is she traped waitting for some LIKE Derek to bring her back to herself. ... I love it! I hope to hell that the baby isn't Michael's. The thought of him having a ... yes don't you just hate them, they will come together soon enough.
# -----
# False
# -----
# People also askWhat is correct sentence?Which is correct Sally and me or Sally and I?Is it grammatically correct to say her and I?Do you say you and John or John?
# -----
# False
# -----
# ...

# %%
# import urllib

# query = '\"aww poor Tom and Harry they get back together. Harry deserves everything he is getting from Tom. please update.\"'
# query = urllib.parse.quote_plus(query) # Format into URL encoding
# number_result = 20

# import requests
# from fake_useragent import UserAgent
# from bs4 import BeautifulSoup

# ua = UserAgent()

# google_url = "https://www.google.com/search?q=" + query + "&num=" + str(number_result)
# response = requests.get(google_url, {"User-Agent": ua.random})
# soup = BeautifulSoup(response.text, "html.parser")
# export = str(soup)
# print(export)
